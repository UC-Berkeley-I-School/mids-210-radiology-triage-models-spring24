# %% [markdown]
# # **Computer Vision Model - Base Case**

# %% [markdown]
# **Objective**: Implement a base case CNN to detect one of the 6 findings in a chest x-ray from mimiciv radiology images selected by the team for the Capstone project

# %% [markdown]
# **Data**: Train, validate and test set of images have been created and stored on the team google drive (`Download` links: [images](?) and [labels](?)). For the base case, the smaller samples set will be used to train the model. Even a sub_sample data set was created for the initial testing of the algorithm.

# %% [markdown]
# # 1. Installation & Packages Setup
# <div style="float:left; font-size:0.7em;"><a href="#returnToTop">Return to Top</a></div> <a id='setup'></a>

# %%
#!pip install pydot

# %%
#!apt-get install graphviz -y

# %% [markdown]
# Import the necessary libraries and make sure to replace IMAGE_PATH and LABEL_PATH with the path to the directories where you saved the data.

# %%
# standard
import pandas as pd
import numpy as np
import random
import os
np.random.seed(711)     #recommended to place this command before importing keras

# tf and keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras import backend as K
from tensorflow.keras.utils import plot_model
from tensorflow.keras.backend import clear_session
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.backend import epsilon
from keras import models
from keras import layers
tf.random.set_seed(711)

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score

# plots
import seaborn as sns
import matplotlib.pyplot as plt

#random.seed(711)
# %matplotlib inline
# Out:
# 2024-03-04 11:02:06.832638: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-04 11:02:06.860906: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-04 11:02:06.860927: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-04 11:02:06.861807: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-04 11:02:06.866710: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ---

# %% [markdown]
# # 2. Define Constants & Methods
# <div style="float:left; font-size:0.7em;"><a href="#returnToTop">Return to Top</a></div> <a id='setup'></a>

# %%
# Define image directories
local_base_dir = '/tf/mount/0 Berkeley/0 Spring 2024/w210 Capstone/Project/mimic_data/mimic_images'
latest_processed_file = 'Processed_Image_Data_Feb_28_2024.csv'
latest_file_path = os.path.join(local_base_dir, latest_processed_file)

# %% [markdown]
# # 3. Load Meta Data & Create Model DataSets
# <div style="float:left; font-size:0.7em;"><a href="#returnToTop">Return to Top</a></div> <a id='setup'></a>

# %% [markdown]
# Read previously saved and latest processed image meta file

# %%
# Read the CSV file into a dataframe
data = pd.read_csv(latest_file_path)

# Use patient_id as the index
data.set_index('patient_id', inplace=True)

print(data.info())
data.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16877 entries, 19998562 to 15032392
# Data columns (total 22 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   study_id                                    16877 non-null  int64
#  1   atelectasis                                 16877 non-null  float64
#  2   cardiomegaly                                16877 non-null  float64
#  3   edema                                       16877 non-null  float64
#  4   lung_opacity                                16877 non-null  float64
#  5   pleural_effusion                            16877 non-null  float64
#  6   pneumonia                                   16877 non-null  float64
#  7   data_type                                   16877 non-null  object
#  8   is_sample                                   16877 non-null  bool
#  9   dicom_id                                    16877 non-null  object
#  10  PerformedProcedureStepDescription           16817 non-null  object
#  11  ViewPosition                                16877 non-null  object
#  12  Rows                                        16877 non-null  int64
#  13  Columns                                     16877 non-null  int64
#  14  StudyDate                                   16877 non-null  int64
#  15  StudyTime                                   16877 non-null  float64
#  16  ProcedureCodeSequence_CodeMeaning           16877 non-null  object
#  17  ViewCodeSequence_CodeMeaning                16877 non-null  object
#  18  PatientOrientationCodeSequence_CodeMeaning  16520 non-null  object
#  19  jpg_filename                                16877 non-null  object
#  20  all_zeros                                   16877 non-null  bool
#  21  anomaly                                     16877 non-null  int64
# dtypes: bool(2), float64(7), int64(5), object(8)
# memory usage: 2.7+ MB
# None
#             study_id  atelectasis  cardiomegaly  edema  lung_opacity  \
# patient_id
# 19998562    52252154          0.0           0.0    0.0           0.0
# 13831580    55371824          0.0           0.0    0.0           0.0
#
#             pleural_effusion  pneumonia data_type  is_sample  \
# patient_id
# 19998562                 1.0        0.0      test      False
# 13831580                 0.0        0.0      test      False
#
#                                                 dicom_id  ...  Rows Columns  \
# patient_id                                                ...
# 19998562    e3e5f8c3-14429887-b1181522-445ec3a8-110663c3  ...  3056    2544
# 13831580    f34f44ce-0feade9a-8a71da5b-6e080e42-643cb41d  ...  3056    2544
#
#             StudyDate   StudyTime  ProcedureCodeSequence_CodeMeaning  \
# patient_id
# 19998562     21660321  224219.015                 CHEST (PA AND LAT)
# 13831580     22031114  210815.687                 CHEST (PA AND LAT)
#
#             ViewCodeSequence_CodeMeaning  \
# patient_id
# 19998562                postero-anterior
# 13831580                postero-anterior
#
#            PatientOrientationCodeSequence_CodeMeaning  \
# patient_id
# 19998562                                        Erect
# 13831580                                        Erect
#
#                                                  jpg_filename all_zeros  \
# patient_id
# 19998562    https://physionet.org/files/mimic-cxr-jpg/2.0....     False
# 13831580    https://physionet.org/files/mimic-cxr-jpg/2.0....      True
#
#            anomaly
# patient_id
# 19998562         1
# 13831580         1
#
# [2 rows x 22 columns]

# %% [markdown]
# Add the '.jpg' extension to 'dicom_id" values

# %%
# Append '.jpg' to each filename in the dicom_id column for all X dataframes
data['dicom_id'] = data['dicom_id'].apply(lambda x: x + '.jpg')

# %% [markdown]
# Create train, validate & test data sets

# %%
# Create separate dataframes for train, validate, and test
train = data[data['data_type'] == 'train']
validate = data[data['data_type'] == 'validate']
test = data[data['data_type'] == 'test']

# Create separate dataframes for sample_train, sample_validate, and sample_test
sample_train = train[train['is_sample'] == True]
sample_validate = validate[validate['is_sample'] == True]
sample_test = test[test['is_sample'] == True]

# Split each dataframe into X (features; in this case the image file name) and y (labels)
# Define columns for X and y
X_columns = ['dicom_id']
y_columns = ['atelectasis', 'cardiomegaly', 'edema', 'lung_opacity', 'pleural_effusion', 'pneumonia']

# Split for train
X_train = train[X_columns]
y_train = train[y_columns]

# Split for validate
X_validate = validate[X_columns]
y_validate = validate[y_columns]

# Split for test
X_test = test[X_columns]
y_test = test[y_columns]

# Split for sample train
X_sample_train = sample_train[X_columns]
y_sample_train = sample_train[y_columns]

# Split for sample validate
X_sample_validate = sample_validate[X_columns]
y_sample_validate = sample_validate[y_columns]

# Split for sample test
X_sample_test = sample_test[X_columns]
y_sample_test = sample_test[y_columns]

# Split for sample train
X_sample_train = sample_train[X_columns]
y_sample_train = sample_train[y_columns]

# Split for sample validate
X_sample_validate = sample_validate[X_columns]
y_sample_validate = sample_validate[y_columns]

# Split for sample test
X_sample_test = sample_test[X_columns]
y_sample_test = sample_test[y_columns]

# %% [markdown]
# Create an additional sub_sample data set for initial trial of model

# %%
# Function to check if any disease is present
def any_disease_present(row):
    return (row > 0).any().astype(int)

# Apply the function to create a new column for simplified stratification
# Ensure you're working on a copy to avoid SettingWithCopyWarning
y_sample_train = y_sample_train.copy()
y_sample_validate = y_sample_validate.copy()
y_sample_test = y_sample_test.copy()

y_sample_train['any_disease'] = y_sample_train.apply(any_disease_present, axis=1)
y_sample_validate['any_disease'] = y_sample_validate.apply(any_disease_present, axis=1)
y_sample_test['any_disease'] = y_sample_test.apply(any_disease_present, axis=1)

# Define a function for creating stratified subsets
def create_stratified_subset(X, y, stratify_col, subset_size=0.1):
    _, X_sub, _, y_sub = train_test_split(X, y, test_size=subset_size, stratify=y[stratify_col], random_state=711)
    return X_sub, y_sub.drop(columns=[stratify_col])

# Create stratified subsets based on the presence of any disease
X_sub_sample_train, y_sub_sample_train = create_stratified_subset(X_sample_train, y_sample_train, 'any_disease', 0.1)
X_sub_sample_validate, y_sub_sample_validate = create_stratified_subset(X_sample_validate, y_sample_validate, 'any_disease', 0.1)
X_sub_sample_test, y_sub_sample_test = create_stratified_subset(X_sample_test, y_sample_test, 'any_disease', 0.1)

# %% [markdown]
# Verify results

# %%
# Create a dictionary to hold all the X and Y dataframes
dataframes = {
    'X_train': X_train,
    'y_train': y_train,
    'X_validate': X_validate,
    'y_validate': y_validate,
    'X_test': X_test,
    'y_test': y_test,
    'X_sample_train': X_sample_train,
    'y_sample_train': y_sample_train,
    'X_sample_validate': X_sample_validate,
    'y_sample_validate': y_sample_validate,
    'X_sample_test': X_sample_test,
    'y_sample_test': y_sample_test,
    'X_sub_sample_train': X_sub_sample_train,
    'y_sub_sample_train': y_sub_sample_train,
    'X_sub_sample_validate': X_sub_sample_validate,
    'y_sub_sample_validate': y_sub_sample_validate,
    'X_sub_sample_test': X_sub_sample_test,
    'y_sub_sample_test': y_sub_sample_test
}

# Loop through the dictionary and print out the shapes
for name, df in dataframes.items():
    print(f"{name} shape: {df.shape}")
# Out:
# X_train shape: (11249, 1)
# y_train shape: (11249, 6)
# X_validate shape: (2814, 1)
# y_validate shape: (2814, 6)
# X_test shape: (2814, 1)
# y_test shape: (2814, 6)
# X_sample_train shape: (1124, 1)
# y_sample_train shape: (1124, 7)
# X_sample_validate shape: (282, 1)
# y_sample_validate shape: (282, 7)
# X_sample_test shape: (282, 1)
# y_sample_test shape: (282, 7)
# X_sub_sample_train shape: (113, 1)
# y_sub_sample_train shape: (113, 6)
# X_sub_sample_validate shape: (29, 1)
# y_sub_sample_validate shape: (29, 6)
# X_sub_sample_test shape: (29, 1)
# y_sub_sample_test shape: (29, 6)

# %% [markdown]
# Check imbalance of labels

# %%
# Define the list of labels
labels = ['atelectasis', 'cardiomegaly', 'edema', 'lung_opacity', 'pleural_effusion', 'pneumonia']

def calculate_percentages(y_df):
    percentages = []
    for label in labels:
        positive_cases = y_df[label].sum()
        total_cases = len(y_df)
        percentage = (positive_cases / total_cases) * 100
        percentages.append(percentage)
    all_zeros_percentage = ((y_df[labels] == 0).all(axis=1).sum() / total_cases) * 100
    percentages.append(all_zeros_percentage)
    return percentages

def calculate_counts(y_df):
    counts = []
    for label in labels:
        positive_cases = y_df[label].sum()
        counts.append(positive_cases)
    all_zeros_count = (y_df[labels] == 0).all(axis=1).sum()
    counts.append(all_zeros_count)
    return counts

# List of datasets and their names
datasets = {
    'Train': y_train,
    'Validate': y_validate,
    'Test': y_test,
    'S Train': y_sample_train,
    'S Val': y_sample_validate,
    'S Test': y_sample_test,
    'Sub S Train': y_sub_sample_train,
    'Sub S Val': y_sub_sample_validate,
    'Sub S Test': y_sub_sample_test
}

# Calculate percentages and counts for all datasets
percentages = {name: calculate_percentages(df) for name, df in datasets.items()}
counts = {name: calculate_counts(df) for name, df in datasets.items()}

# Convert to DataFrames
percentages_df = pd.DataFrame(percentages, index=labels+['All Zeros']).style.format('{:.2f}%')
counts_df = pd.DataFrame(counts, index=labels+['All Zeros']).astype(int)  # Ensure counts are integers

# Display the styled DataFrame for percentages
print("Percentages:")
display(percentages_df)

# Display the DataFrame for counts
print("Counts:")
display(counts_df)
# Out:
# Percentages:
# <style type="text/css">
# </style>
# <table id="T_8dd68">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dd68_level0_col0" class="col_heading level0 col0" >Train</th>
#       <th id="T_8dd68_level0_col1" class="col_heading level0 col1" >Validate</th>
#       <th id="T_8dd68_level0_col2" class="col_heading level0 col2" >Test</th>
#       <th id="T_8dd68_level0_col3" class="col_heading level0 col3" >S Train</th>
#       <th id="T_8dd68_level0_col4" class="col_heading level0 col4" >S Val</th>
#       <th id="T_8dd68_level0_col5" class="col_heading level0 col5" >S Test</th>
#       <th id="T_8dd68_level0_col6" class="col_heading level0 col6" >Sub S Train</th>
#       <th id="T_8dd68_level0_col7" class="col_heading level0 col7" >Sub S Val</th>
#       <th id="T_8dd68_level0_col8" class="col_heading level0 col8" >Sub S Test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dd68_level0_row0" class="row_heading level0 row0" >atelectasis</th>
#       <td id="T_8dd68_row0_col0" class="data row0 col0" >12.88%</td>
#       <td id="T_8dd68_row0_col1" class="data row0 col1" >12.86%</td>
#       <td id="T_8dd68_row0_col2" class="data row0 col2" >14.54%</td>
#       <td id="T_8dd68_row0_col3" class="data row0 col3" >11.92%</td>
#       <td id="T_8dd68_row0_col4" class="data row0 col4" >13.12%</td>
#       <td id="T_8dd68_row0_col5" class="data row0 col5" >14.54%</td>
#       <td id="T_8dd68_row0_col6" class="data row0 col6" >14.16%</td>
#       <td id="T_8dd68_row0_col7" class="data row0 col7" >13.79%</td>
#       <td id="T_8dd68_row0_col8" class="data row0 col8" >13.79%</td>
#     </tr>
#     <tr>
#       <th id="T_8dd68_level0_row1" class="row_heading level0 row1" >cardiomegaly</th>
#       <td id="T_8dd68_row1_col0" class="data row1 col0" >10.06%</td>
#       <td id="T_8dd68_row1_col1" class="data row1 col1" >9.91%</td>
#       <td id="T_8dd68_row1_col2" class="data row1 col2" >9.22%</td>
#       <td id="T_8dd68_row1_col3" class="data row1 col3" >11.12%</td>
#       <td id="T_8dd68_row1_col4" class="data row1 col4" >9.93%</td>
#       <td id="T_8dd68_row1_col5" class="data row1 col5" >9.22%</td>
#       <td id="T_8dd68_row1_col6" class="data row1 col6" >9.73%</td>
#       <td id="T_8dd68_row1_col7" class="data row1 col7" >6.90%</td>
#       <td id="T_8dd68_row1_col8" class="data row1 col8" >10.34%</td>
#     </tr>
#     <tr>
#       <th id="T_8dd68_level0_row2" class="row_heading level0 row2" >edema</th>
#       <td id="T_8dd68_row2_col0" class="data row2 col0" >8.24%</td>
#       <td id="T_8dd68_row2_col1" class="data row2 col1" >8.21%</td>
#       <td id="T_8dd68_row2_col2" class="data row2 col2" >7.80%</td>
#       <td id="T_8dd68_row2_col3" class="data row2 col3" >7.83%</td>
#       <td id="T_8dd68_row2_col4" class="data row2 col4" >7.09%</td>
#       <td id="T_8dd68_row2_col5" class="data row2 col5" >7.80%</td>
#       <td id="T_8dd68_row2_col6" class="data row2 col6" >6.19%</td>
#       <td id="T_8dd68_row2_col7" class="data row2 col7" >10.34%</td>
#       <td id="T_8dd68_row2_col8" class="data row2 col8" >6.90%</td>
#     </tr>
#     <tr>
#       <th id="T_8dd68_level0_row3" class="row_heading level0 row3" >lung_opacity</th>
#       <td id="T_8dd68_row3_col0" class="data row3 col0" >19.45%</td>
#       <td id="T_8dd68_row3_col1" class="data row3 col1" >19.40%</td>
#       <td id="T_8dd68_row3_col2" class="data row3 col2" >19.50%</td>
#       <td id="T_8dd68_row3_col3" class="data row3 col3" >20.28%</td>
#       <td id="T_8dd68_row3_col4" class="data row3 col4" >20.21%</td>
#       <td id="T_8dd68_row3_col5" class="data row3 col5" >19.50%</td>
#       <td id="T_8dd68_row3_col6" class="data row3 col6" >21.24%</td>
#       <td id="T_8dd68_row3_col7" class="data row3 col7" >17.24%</td>
#       <td id="T_8dd68_row3_col8" class="data row3 col8" >10.34%</td>
#     </tr>
#     <tr>
#       <th id="T_8dd68_level0_row4" class="row_heading level0 row4" >pleural_effusion</th>
#       <td id="T_8dd68_row4_col0" class="data row4 col0" >12.26%</td>
#       <td id="T_8dd68_row4_col1" class="data row4 col1" >12.26%</td>
#       <td id="T_8dd68_row4_col2" class="data row4 col2" >9.22%</td>
#       <td id="T_8dd68_row4_col3" class="data row4 col3" >10.77%</td>
#       <td id="T_8dd68_row4_col4" class="data row4 col4" >12.41%</td>
#       <td id="T_8dd68_row4_col5" class="data row4 col5" >9.22%</td>
#       <td id="T_8dd68_row4_col6" class="data row4 col6" >8.85%</td>
#       <td id="T_8dd68_row4_col7" class="data row4 col7" >20.69%</td>
#       <td id="T_8dd68_row4_col8" class="data row4 col8" >6.90%</td>
#     </tr>
#     <tr>
#       <th id="T_8dd68_level0_row5" class="row_heading level0 row5" >pneumonia</th>
#       <td id="T_8dd68_row5_col0" class="data row5 col0" >6.53%</td>
#       <td id="T_8dd68_row5_col1" class="data row5 col1" >6.54%</td>
#       <td id="T_8dd68_row5_col2" class="data row5 col2" >4.96%</td>
#       <td id="T_8dd68_row5_col3" class="data row5 col3" >6.67%</td>
#       <td id="T_8dd68_row5_col4" class="data row5 col4" >7.80%</td>
#       <td id="T_8dd68_row5_col5" class="data row5 col5" >4.96%</td>
#       <td id="T_8dd68_row5_col6" class="data row5 col6" >8.85%</td>
#       <td id="T_8dd68_row5_col7" class="data row5 col7" >6.90%</td>
#       <td id="T_8dd68_row5_col8" class="data row5 col8" >6.90%</td>
#     </tr>
#     <tr>
#       <th id="T_8dd68_level0_row6" class="row_heading level0 row6" >All Zeros</th>
#       <td id="T_8dd68_row6_col0" class="data row6 col0" >54.97%</td>
#       <td id="T_8dd68_row6_col1" class="data row6 col1" >55.01%</td>
#       <td id="T_8dd68_row6_col2" class="data row6 col2" >57.09%</td>
#       <td id="T_8dd68_row6_col3" class="data row6 col3" >55.25%</td>
#       <td id="T_8dd68_row6_col4" class="data row6 col4" >55.32%</td>
#       <td id="T_8dd68_row6_col5" class="data row6 col5" >57.09%</td>
#       <td id="T_8dd68_row6_col6" class="data row6 col6" >54.87%</td>
#       <td id="T_8dd68_row6_col7" class="data row6 col7" >55.17%</td>
#       <td id="T_8dd68_row6_col8" class="data row6 col8" >58.62%</td>
#     </tr>
#   </tbody>
# </table>
# Counts:
#                   Train  Validate  Test  S Train  S Val  S Test  Sub S Train  \
# atelectasis        1449       362    41      134     37      41           16
# cardiomegaly       1132       279    26      125     28      26           11
# edema               927       231    22       88     20      22            7
# lung_opacity       2188       546    55      228     57      55           24
# pleural_effusion   1379       345    26      121     35      26           10
# pneumonia           735       184    14       75     22      14           10
# All Zeros          6184      1548   161      621    156     161           62
#
#                   Sub S Val  Sub S Test
# atelectasis               4           4
# cardiomegaly              2           3
# edema                     3           2
# lung_opacity              5           3
# pleural_effusion          6           2
# pneumonia                 2           2
# All Zeros                16          17

# %% [markdown]
# ## Discussion:
# The percentages shown above indicate a significant imbalance in the dataset. When the positive instances for a label constitute a small fraction of the total (as is the case here, with values ranging between approximately 6% and 20%), it suggests that the dataset is heavily skewed towards negative instances (in this case, the absence of a particular condition).
#
# Moreover, the fact that 54.97% of our records have all labels set to zero (meaning no conditions are present) further emphasizes this imbalance. This can pose challenges for our machine learning models, as it might become biased towards predicting the negative class due to its higher prevalence in the training data.
#
# To address this imbalance, especially if it manifests itself during testing, we might consider undersampling the majority class or applying different weights to the classes during model training to penalize misclassification of the minority class more heavily.

# %% [markdown]
# ---

# %% [markdown]
# # 3. Inspect Available Images
# <div style="float:left; font-size:0.7em;"><a href="#returnToTop">Return to Top</a></div> <a id='setup'></a>

# %%
# Define the subdirectory for train images
train_images_dir = 'size_512/sample_images_512/sample_train_images_512'   #  Using the 512x512 directory

# Construct the full path to the train images directory
images_path = os.path.join(local_base_dir, train_images_dir)

# Initialize variables
images = []
print('Sample of images in sample train dataset:')

# Load the first 8 images
for idx, img_file in enumerate(os.listdir(images_path)):
    if idx < 6:  # Only process the first 6 images
        img = load_img(os.path.join(images_path, img_file))
        images.append(img)
    else:
        break  # Stop the loop after the first 6 images

# Set up the subplot dimensions
nrows, ncols = 2, 3  
fig, axs = plt.subplots(nrows, ncols, figsize=(20, 10))

# Display the images
for i in range(nrows):
    for j in range(ncols):
        indx = i * ncols + j  # Correct calculation of index
        if indx < len(images):  # Check to avoid IndexError
            axs[i, j].imshow(images[indx])
            axs[i, j].axis('off')  # Remove axes

plt.show()
# Out:
# Sample of images in sample train dataset:

# %% [markdown]
# ---

# %% [markdown]
# # 4. Image Normalization & Data Generation
# <div style="float:left; font-size:0.7em;"><a href="#returnToTop">Return to Top</a></div> <a id='setup'></a>

# %% [markdown]
# # 4.1 Choice of Samples Set
# <div style="float:left; font-size:0.7em;"><a href="#returnToTop">Return to Top</a></div> <a id='setup'></a>

# %%
# Select samples to be used: for now let's use the sub_sample set to test the algorithm 
sample_directory = os.path.join(local_base_dir, 'size_512/sample_images_512')
select_train_dir = 'sample_train_images_512'
select_val_dir   = 'sample_validate_images_512'
select_test_dir  = 'sample_test_images_512'
target_size = 512
X_trn = X_sample_train
y_trn = y_sample_train
X_val = X_sample_validate
y_val = y_sample_validate
X_test = X_sample_test
y_test = y_sample_test

# %% [markdown]
# # 4.2 Generate Image Data
# <div style="float:left; font-size:0.7em;"><a href="#returnToTop">Return to Top</a></div> <a id='setup'></a>

# %%
# Create the image data generator function 
def prepare_data_generators(X_train, y_train, X_val, y_val, X_test, y_test, train_dir, val_dir, test_dir, target_size=256):
    # Create ImageDataGenerator instances with normalization
    train_datagen = ImageDataGenerator(rescale=1./255)
    val_datagen   = ImageDataGenerator(rescale=1./255)
    test_datagen  = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_dataframe(
        dataframe=X_train.join(y_train),
        directory=train_dir,
        x_col='dicom_id',
        y_col=['atelectasis', 'cardiomegaly', 'edema', 'lung_opacity', 'pleural_effusion', 'pneumonia'],
        target_size=(target_size, target_size),
        color_mode='rgb',
        class_mode='raw',
        batch_size=32,
        shuffle=True,
        seed=711
    )

    val_generator = val_datagen.flow_from_dataframe(
        dataframe=X_val.join(y_val),
        directory=val_dir,
        x_col='dicom_id',
        y_col=['atelectasis', 'cardiomegaly', 'edema', 'lung_opacity', 'pleural_effusion', 'pneumonia'],
        target_size=(target_size, target_size),
        color_mode='rgb',
        class_mode='raw',
        batch_size=32,
        shuffle=False,
        seed=711
    )

    test_generator = test_datagen.flow_from_dataframe(
        dataframe=X_test.join(y_test),
        directory=test_dir,
        x_col='dicom_id',
        y_col=['atelectasis', 'cardiomegaly', 'edema', 'lung_opacity', 'pleural_effusion', 'pneumonia'],
        target_size=(target_size, target_size),
        color_mode='rgb',
        class_mode='raw',
        batch_size=32,
        shuffle=False,
        seed=711
    )

    return train_generator, val_generator, test_generator

# %%
# Generate the image data
train_generator, val_generator, test_generator = prepare_data_generators(
    X_trn, y_trn, 
    X_val, y_val, 
    X_test, y_test, 
    os.path.join(sample_directory, select_train_dir), 
    os.path.join(sample_directory, select_val_dir), 
    os.path.join(sample_directory, select_test_dir),
    target_size = target_size
)
# Out:
# Found 1124 validated image filenames.
# Found 282 validated image filenames.
# Found 282 validated image filenames.

# %%
# Fetch a single batch from the train_generator
x_batch, y_batch = next(train_generator)

# Print the shape of the batch
print("Shape of x_batch:", x_batch.shape)
print("Shape of y_batch:", y_batch.shape)
# Out:
# Shape of x_batch: (32, 512, 512, 3)
# Shape of y_batch: (32, 6)

# %% [markdown]
# # 5. Model
# <div style="float:left; font-size:0.7em;"><a href="#returnToTop">Return to Top</a></div> <a id='setup'></a>

# %% [markdown]
# ``First let's build a custom f1 score function since it is not avaolabel though tf.keras``

# %%
# Define the custom metric class
class ExtendedMultiLabelMetrics(tf.keras.metrics.Metric):
    def __init__(self, num_labels, name='extended_multi_label_metrics', **kwargs):
        super(ExtendedMultiLabelMetrics, self).__init__(name=name, **kwargs)
        self.num_labels = num_labels
        self.precision = [tf.keras.metrics.Precision(name=f'precision_{i}') for i in range(num_labels)]
        self.recall = [tf.keras.metrics.Recall(name=f'recall_{i}') for i in range(num_labels)]
        self.auc = [tf.keras.metrics.AUC(name=f'auc_{i}') for i in range(num_labels)]
        self.f1_scores = [self.add_weight(name=f'f1_score_{i}', initializer='zeros') for i in range(num_labels)]

    def update_state(self, y_true, y_pred, sample_weight=None):
        for i in range(self.num_labels):
            self.precision[i].update_state(y_true[:, i], y_pred[:, i])
            self.recall[i].update_state(y_true[:, i], y_pred[:, i])
            self.auc[i].update_state(y_true[:, i], y_pred[:, i])
            p = self.precision[i].result()
            r = self.recall[i].result()
            self.f1_scores[i].assign(2 * ((p * r) / (p + r + tf.keras.backend.epsilon())))

    def result(self):
        # Return both individual and average metrics
        metrics = {}
        for i in range(self.num_labels):
            metrics[f'precision_{i}'] = self.precision[i].result()
            metrics[f'recall_{i}'] = self.recall[i].result()
            metrics[f'auc_{i}'] = self.auc[i].result()
            metrics[f'f1_score_{i}'] = self.f1_scores[i]

        metrics['avg_f1_score'] = tf.reduce_mean(self.f1_scores)
        metrics['avg_precision'] = tf.reduce_mean([p.result() for p in self.precision])
        metrics['avg_recall'] = tf.reduce_mean([r.result() for r in self.recall])
        metrics['avg_auc'] = tf.reduce_mean([auc.result() for auc in self.auc])
        return metrics

    def reset_state(self):
        for i in range(self.num_labels):
            self.precision[i].reset_state()
            self.recall[i].reset_state()
            self.auc[i].reset_state()
            self.f1_scores[i].assign(0)

# %% [markdown]
# ``Build model``

# %%
n_classes = 6        # number of classes/labels (pathologial findings)
shape_size = 512

# Initialize the extended multi-label metrics class
extended_multi_label_metrics = ExtendedMultiLabelMetrics(num_labels=n_classes)

# Clear any previous session to free memory
clear_session()

model = tf.keras.Sequential()

# add first convolution layer
model.add(tf.keras.layers.Conv2D(
    filters=32,
    kernel_size=(5, 5),
    strides=(1, 1),
    padding='same',
    activation='relu',
    input_shape=(shape_size, shape_size, 3)))

# First max pooling layer
model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))  # this will reduce the spatial dimensions by half

# Second convolutional layer
model.add(tf.keras.layers.Conv2D(
    filters=64,
    kernel_size=(5, 5),
    strides=(1, 1),
    padding='same',
    activation='relu'))

# Second max pooling layer
model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))

# Flatten the output to feed into a fully connected layer
model.add(tf.keras.layers.Flatten())

# Fully connected layer with 1024 units
model.add(tf.keras.layers.Dense(units=256, activation='relu'))    # attempt to avoid memory issues (change from: units = 1024)

# Dropout layer for regularization
model.add(tf.keras.layers.Dropout(rate=0.5))

# Output layer with 'n_classes' units and sigmoid activation function for multi-label classification
model.add(tf.keras.layers.Dense(units=n_classes, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=[extended_multi_label_metrics]
             )

# Print model summary
model.summary()

# Plot the model
#tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)
# Out:
# 2024-03-04 11:02:14.173078: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-04 11:02:14.180412: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-04 11:02:14.180453: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-04 11:02:14.184714: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-04 11:02:14.184754: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-04 11:02:14.184763: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-04 11:02:14.288387: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-04 11:02:14.288425: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-04 11:02:14.288430: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-03-04 11:02:14.288449: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-04 11:02:14.288465: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9585 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 512, 512, 32)      2432
#
#  max_pooling2d (MaxPooling2  (None, 256, 256, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 64)      51264
#
#  max_pooling2d_1 (MaxPoolin  (None, 128, 128, 64)      0
#  g2D)
#
#  flatten (Flatten)           (None, 1048576)           0
#
#  dense (Dense)               (None, 256)               268435712
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 268490950 (1.00 GB)
# Trainable params: 268490950 (1.00 GB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model using the generators
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator
)
# Out:
# Epoch 1/50
# 2024-03-04 11:02:39.424833: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 2024-03-04 11:02:45.937969: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fa9b8afb670 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-03-04 11:02:45.938006: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2024-03-04 11:02:45.942570: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709550166.000931   16146 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 36/36 [==============================] - 60s 827ms/step - loss: 0.8194 - precision_0: 0.0000e+00 - recall_0: 0.0000e+00 - auc_0: 0.4664 - f1_score_0: 0.0000e+00 - precision_1: 0.1390 - recall_1: 0.1627 - auc_1: 0.4760 - f1_score_1: 0.1289 - precision_2: 0.0745 - recall_2: 0.1424 - auc_2: 0.4928 - f1_score_2: 0.0869 - precision_3: 0.1034 - recall_3: 0.0568 - auc_3: 0.4967 - f1_score_3: 0.0693 - precision_4: 0.1175 - recall_4: 0.0306 - auc_4: 0.4932 - f1_score_4: 0.0469 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - auc_5: 0.4038 - f1_score_5: 0.0000e+00 - avg_f1_score: 0.0553 - avg_precision: 0.0724 - avg_recall: 0.0654 - avg_auc: 0.4715 - val_loss: 0.3536 - val_precision_0: 0.0000e+00 - val_recall_0: 0.0000e+00 - val_auc_0: 0.5475 - val_f1_score_0: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.6408 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.6234 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_auc_3: 0.5156 - val_f1_score_3: 0.0000e+00 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.6238 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.3294 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0000e+00 - val_avg_precision: 0.0000e+00 - val_avg_recall: 0.0000e+00 - val_avg_auc: 0.5468
# Epoch 2/50
# 36/36 [==============================] - 17s 488ms/step - loss: 0.3896 - precision_0: 0.0000e+00 - recall_0: 0.0000e+00 - auc_0: 0.5266 - f1_score_0: 0.0000e+00 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - auc_1: 0.5223 - f1_score_1: 0.0000e+00 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - auc_2: 0.5168 - f1_score_2: 0.0000e+00 - precision_3: 0.4400 - recall_3: 0.0277 - auc_3: 0.5328 - f1_score_3: 0.0515 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - auc_4: 0.4824 - f1_score_4: 0.0000e+00 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - auc_5: 0.5009 - f1_score_5: 0.0000e+00 - avg_f1_score: 0.0086 - avg_precision: 0.0733 - avg_recall: 0.0046 - avg_auc: 0.5136 - val_loss: 0.3554 - val_precision_0: 0.0000e+00 - val_recall_0: 0.0000e+00 - val_auc_0: 0.6311 - val_f1_score_0: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.6051 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.6842 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_auc_3: 0.5844 - val_f1_score_3: 0.0000e+00 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.5573 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.3881 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0000e+00 - val_avg_precision: 0.0000e+00 - val_avg_recall: 0.0000e+00 - val_avg_auc: 0.5750
# Epoch 3/50
# 36/36 [==============================] - 18s 498ms/step - loss: 0.3297 - precision_0: 0.0000e+00 - recall_0: 0.0000e+00 - auc_0: 0.6440 - f1_score_0: 0.0000e+00 - precision_1: 0.3589 - recall_1: 0.0178 - auc_1: 0.6726 - f1_score_1: 0.0339 - precision_2: 0.3784 - recall_2: 0.0103 - auc_2: 0.6723 - f1_score_2: 0.0199 - precision_3: 0.3917 - recall_3: 0.0741 - auc_3: 0.6878 - f1_score_3: 0.1244 - precision_4: 0.5611 - recall_4: 0.0397 - auc_4: 0.6785 - f1_score_4: 0.0724 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - auc_5: 0.5850 - f1_score_5: 0.0000e+00 - avg_f1_score: 0.0418 - avg_precision: 0.2817 - avg_recall: 0.0236 - avg_auc: 0.6567 - val_loss: 0.3639 - val_precision_0: 0.0000e+00 - val_recall_0: 0.0000e+00 - val_auc_0: 0.6510 - val_f1_score_0: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5676 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.6134 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2500 - val_recall_3: 0.0175 - val_auc_3: 0.5915 - val_f1_score_3: 0.0328 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.5497 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.3897 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0055 - val_avg_precision: 0.0417 - val_avg_recall: 0.0029 - val_avg_auc: 0.5605
# Epoch 4/50
# 36/36 [==============================] - 16s 435ms/step - loss: 0.2911 - precision_0: 0.7264 - recall_0: 0.1502 - auc_0: 0.8044 - f1_score_0: 0.2470 - precision_1: 0.6880 - recall_1: 0.1043 - auc_1: 0.8120 - f1_score_1: 0.1743 - precision_2: 0.6468 - recall_2: 0.0600 - auc_2: 0.7128 - f1_score_2: 0.1078 - precision_3: 0.6860 - recall_3: 0.2802 - auc_3: 0.7864 - f1_score_3: 0.3975 - precision_4: 0.7830 - recall_4: 0.1380 - auc_4: 0.7857 - f1_score_4: 0.2343 - precision_5: 0.0347 - recall_5: 0.0027 - auc_5: 0.7572 - f1_score_5: 0.0050 - avg_f1_score: 0.1943 - avg_precision: 0.5941 - avg_recall: 0.1226 - avg_auc: 0.7764 - val_loss: 0.3868 - val_precision_0: 0.0000e+00 - val_recall_0: 0.0000e+00 - val_auc_0: 0.6338 - val_f1_score_0: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5148 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5487 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.1111 - val_recall_3: 0.0175 - val_auc_3: 0.6093 - val_f1_score_3: 0.0303 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4701 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4435 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0051 - val_avg_precision: 0.0185 - val_avg_recall: 0.0029 - val_avg_auc: 0.5367
# Epoch 5/50
# 36/36 [==============================] - 20s 495ms/step - loss: 0.2238 - precision_0: 0.8946 - recall_0: 0.3313 - auc_0: 0.8689 - f1_score_0: 0.4792 - precision_1: 0.9047 - recall_1: 0.3007 - auc_1: 0.8877 - f1_score_1: 0.4479 - precision_2: 0.9364 - recall_2: 0.3043 - auc_2: 0.9032 - f1_score_2: 0.4532 - precision_3: 0.7811 - recall_3: 0.4310 - auc_3: 0.8719 - f1_score_3: 0.5547 - precision_4: 0.9457 - recall_4: 0.2349 - auc_4: 0.9003 - f1_score_4: 0.3743 - precision_5: 0.8501 - recall_5: 0.1217 - auc_5: 0.8923 - f1_score_5: 0.2100 - avg_f1_score: 0.4199 - avg_precision: 0.8854 - avg_recall: 0.2873 - avg_auc: 0.8874 - val_loss: 0.4480 - val_precision_0: 0.1000 - val_recall_0: 0.0270 - val_auc_0: 0.5726 - val_f1_score_0: 0.0426 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4962 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5123 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2857 - val_recall_3: 0.0702 - val_auc_3: 0.6044 - val_f1_score_3: 0.1127 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4379 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4284 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0259 - val_avg_precision: 0.0643 - val_avg_recall: 0.0162 - val_avg_auc: 0.5087
# Epoch 6/50
# 36/36 [==============================] - 16s 437ms/step - loss: 0.1502 - precision_0: 0.8948 - recall_0: 0.6610 - auc_0: 0.9625 - f1_score_0: 0.7595 - precision_1: 0.9463 - recall_1: 0.5661 - auc_1: 0.9521 - f1_score_1: 0.7061 - precision_2: 0.9318 - recall_2: 0.5821 - auc_2: 0.9789 - f1_score_2: 0.7135 - precision_3: 0.8853 - recall_3: 0.6154 - auc_3: 0.9543 - f1_score_3: 0.7250 - precision_4: 0.8707 - recall_4: 0.5579 - auc_4: 0.9644 - f1_score_4: 0.6759 - precision_5: 0.8381 - recall_5: 0.3597 - auc_5: 0.9574 - f1_score_5: 0.5011 - avg_f1_score: 0.6802 - avg_precision: 0.8945 - avg_recall: 0.5570 - avg_auc: 0.9616 - val_loss: 0.5406 - val_precision_0: 0.1429 - val_recall_0: 0.0270 - val_auc_0: 0.5360 - val_f1_score_0: 0.0455 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5456 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.4323 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3333 - val_recall_3: 0.1404 - val_auc_3: 0.6065 - val_f1_score_3: 0.1975 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4302 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4143 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0405 - val_avg_precision: 0.0794 - val_avg_recall: 0.0279 - val_avg_auc: 0.4942
# Epoch 7/50
# 36/36 [==============================] - 18s 440ms/step - loss: 0.1058 - precision_0: 0.9311 - recall_0: 0.6784 - auc_0: 0.9753 - f1_score_0: 0.7830 - precision_1: 0.9560 - recall_1: 0.7498 - auc_1: 0.9937 - f1_score_1: 0.8401 - precision_2: 0.9142 - recall_2: 0.6781 - auc_2: 0.9822 - f1_score_2: 0.7769 - precision_3: 0.9088 - recall_3: 0.7398 - auc_3: 0.9653 - f1_score_3: 0.8149 - precision_4: 0.9717 - recall_4: 0.6772 - auc_4: 0.9814 - f1_score_4: 0.7978 - precision_5: 0.9785 - recall_5: 0.5896 - auc_5: 0.9780 - f1_score_5: 0.7345 - avg_f1_score: 0.7912 - avg_precision: 0.9434 - avg_recall: 0.6855 - avg_auc: 0.9793 - val_loss: 0.5993 - val_precision_0: 0.0000e+00 - val_recall_0: 0.0000e+00 - val_auc_0: 0.5261 - val_f1_score_0: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5459 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.4975 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3214 - val_recall_3: 0.1579 - val_auc_3: 0.5606 - val_f1_score_3: 0.2118 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4409 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4531 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0353 - val_avg_precision: 0.0536 - val_avg_recall: 0.0263 - val_avg_auc: 0.5040
# Epoch 8/50
# 36/36 [==============================] - 15s 416ms/step - loss: 0.0785 - precision_0: 0.9358 - recall_0: 0.8531 - auc_0: 0.9847 - f1_score_0: 0.8924 - precision_1: 0.9238 - recall_1: 0.8379 - auc_1: 0.9904 - f1_score_1: 0.8777 - precision_2: 0.9711 - recall_2: 0.8502 - auc_2: 0.9942 - f1_score_2: 0.9058 - precision_3: 0.9762 - recall_3: 0.8598 - auc_3: 0.9901 - f1_score_3: 0.9140 - precision_4: 0.9210 - recall_4: 0.7570 - auc_4: 0.9811 - f1_score_4: 0.8304 - precision_5: 0.7879 - recall_5: 0.6699 - auc_5: 0.9824 - f1_score_5: 0.7179 - avg_f1_score: 0.8564 - avg_precision: 0.9193 - avg_recall: 0.8047 - avg_auc: 0.9871 - val_loss: 0.7035 - val_precision_0: 0.0000e+00 - val_recall_0: 0.0000e+00 - val_auc_0: 0.4988 - val_f1_score_0: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5147 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5364 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2647 - val_recall_3: 0.1579 - val_auc_3: 0.5690 - val_f1_score_3: 0.1978 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4854 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4295 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0330 - val_avg_precision: 0.0441 - val_avg_recall: 0.0263 - val_avg_auc: 0.5056
# Epoch 9/50
# 36/36 [==============================] - 17s 480ms/step - loss: 0.0614 - precision_0: 0.9165 - recall_0: 0.8448 - auc_0: 0.9663 - f1_score_0: 0.8789 - precision_1: 0.9844 - recall_1: 0.9166 - auc_1: 0.9972 - f1_score_1: 0.9491 - precision_2: 0.9888 - recall_2: 0.8834 - auc_2: 0.9972 - f1_score_2: 0.9328 - precision_3: 0.9460 - recall_3: 0.8788 - auc_3: 0.9907 - f1_score_3: 0.9110 - precision_4: 0.9348 - recall_4: 0.8774 - auc_4: 0.9960 - f1_score_4: 0.9049 - precision_5: 0.9934 - recall_5: 0.7749 - auc_5: 0.9978 - f1_score_5: 0.8691 - avg_f1_score: 0.9076 - avg_precision: 0.9606 - avg_recall: 0.8626 - avg_auc: 0.9909 - val_loss: 0.9064 - val_precision_0: 0.0000e+00 - val_recall_0: 0.0000e+00 - val_auc_0: 0.5280 - val_f1_score_0: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4940 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.4918 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2000 - val_recall_3: 0.0526 - val_auc_3: 0.5890 - val_f1_score_3: 0.0833 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4699 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4511 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0139 - val_avg_precision: 0.0333 - val_avg_recall: 0.0088 - val_avg_auc: 0.5040
# Epoch 10/50
# 36/36 [==============================] - 17s 484ms/step - loss: 0.0520 - precision_0: 0.9624 - recall_0: 0.8836 - auc_0: 0.9962 - f1_score_0: 0.9209 - precision_1: 0.9709 - recall_1: 0.9156 - auc_1: 0.9961 - f1_score_1: 0.9421 - precision_2: 0.9321 - recall_2: 0.8855 - auc_2: 0.9936 - f1_score_2: 0.9073 - precision_3: 0.9610 - recall_3: 0.9034 - auc_3: 0.9967 - f1_score_3: 0.9310 - precision_4: 0.9641 - recall_4: 0.8341 - auc_4: 0.9947 - f1_score_4: 0.8925 - precision_5: 0.9167 - recall_5: 0.8116 - auc_5: 0.9958 - f1_score_5: 0.8558 - avg_f1_score: 0.9083 - avg_precision: 0.9512 - avg_recall: 0.8723 - avg_auc: 0.9955 - val_loss: 0.8027 - val_precision_0: 0.2500 - val_recall_0: 0.0270 - val_auc_0: 0.4689 - val_f1_score_0: 0.0488 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5161 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.4859 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2449 - val_recall_3: 0.2105 - val_auc_3: 0.5277 - val_f1_score_3: 0.2264 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4382 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4224 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0459 - val_avg_precision: 0.0825 - val_avg_recall: 0.0396 - val_avg_auc: 0.4765
# Epoch 11/50
# 36/36 [==============================] - 15s 433ms/step - loss: 0.0402 - precision_0: 0.9773 - recall_0: 0.8907 - auc_0: 0.9955 - f1_score_0: 0.9307 - precision_1: 0.9599 - recall_1: 0.9408 - auc_1: 0.9967 - f1_score_1: 0.9495 - precision_2: 0.9601 - recall_2: 0.8770 - auc_2: 0.9987 - f1_score_2: 0.9139 - precision_3: 0.9158 - recall_3: 0.9270 - auc_3: 0.9839 - f1_score_3: 0.9210 - precision_4: 0.9428 - recall_4: 0.8877 - auc_4: 0.9857 - f1_score_4: 0.9130 - precision_5: 0.9009 - recall_5: 0.9477 - auc_5: 0.9961 - f1_score_5: 0.9232 - avg_f1_score: 0.9252 - avg_precision: 0.9428 - avg_recall: 0.9118 - avg_auc: 0.9928 - val_loss: 1.0007 - val_precision_0: 0.3333 - val_recall_0: 0.0811 - val_auc_0: 0.5371 - val_f1_score_0: 0.1304 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4916 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.4816 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2258 - val_recall_3: 0.1228 - val_auc_3: 0.5358 - val_f1_score_3: 0.1591 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4821 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4466 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0483 - val_avg_precision: 0.0932 - val_avg_recall: 0.0340 - val_avg_auc: 0.4958
# Epoch 12/50
# 36/36 [==============================] - 18s 450ms/step - loss: 0.0414 - precision_0: 0.9974 - recall_0: 0.9162 - auc_0: 0.9979 - f1_score_0: 0.9547 - precision_1: 0.9834 - recall_1: 0.9138 - auc_1: 0.9925 - f1_score_1: 0.9466 - precision_2: 0.8933 - recall_2: 0.9321 - auc_2: 0.9971 - f1_score_2: 0.9083 - precision_3: 0.9776 - recall_3: 0.9299 - auc_3: 0.9989 - f1_score_3: 0.9530 - precision_4: 0.9542 - recall_4: 0.9654 - auc_4: 0.9990 - f1_score_4: 0.9595 - precision_5: 0.9503 - recall_5: 0.8744 - auc_5: 0.9868 - f1_score_5: 0.9098 - avg_f1_score: 0.9387 - avg_precision: 0.9594 - avg_recall: 0.9219 - avg_auc: 0.9954 - val_loss: 0.8630 - val_precision_0: 0.3846 - val_recall_0: 0.1351 - val_auc_0: 0.4994 - val_f1_score_0: 0.2000 - val_precision_1: 0.1667 - val_recall_1: 0.0357 - val_auc_1: 0.4974 - val_f1_score_1: 0.0588 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.4958 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2093 - val_recall_3: 0.1579 - val_auc_3: 0.5734 - val_f1_score_3: 0.1800 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4702 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4421 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0731 - val_avg_precision: 0.1268 - val_avg_recall: 0.0548 - val_avg_auc: 0.4964
# Epoch 13/50
# 36/36 [==============================] - 17s 412ms/step - loss: 0.0376 - precision_0: 0.9203 - recall_0: 0.9259 - auc_0: 0.9966 - f1_score_0: 0.9201 - precision_1: 0.9800 - recall_1: 0.9344 - auc_1: 0.9989 - f1_score_1: 0.9566 - precision_2: 0.9778 - recall_2: 0.8718 - auc_2: 0.9971 - f1_score_2: 0.9205 - precision_3: 0.9305 - recall_3: 0.9766 - auc_3: 0.9981 - f1_score_3: 0.9523 - precision_4: 0.9849 - recall_4: 0.8992 - auc_4: 0.9989 - f1_score_4: 0.9390 - precision_5: 0.9975 - recall_5: 0.8678 - auc_5: 0.9987 - f1_score_5: 0.9267 - avg_f1_score: 0.9359 - avg_precision: 0.9652 - avg_recall: 0.9126 - avg_auc: 0.9981 - val_loss: 1.0129 - val_precision_0: 0.4000 - val_recall_0: 0.0541 - val_auc_0: 0.5156 - val_f1_score_0: 0.0952 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4940 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.4864 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2500 - val_recall_3: 0.1404 - val_auc_3: 0.5420 - val_f1_score_3: 0.1798 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4957 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4377 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0458 - val_avg_precision: 0.1083 - val_avg_recall: 0.0324 - val_avg_auc: 0.4952
# Epoch 14/50
# 36/36 [==============================] - 17s 480ms/step - loss: 0.0229 - precision_0: 0.9733 - recall_0: 0.9195 - auc_0: 0.9953 - f1_score_0: 0.9454 - precision_1: 0.9989 - recall_1: 0.9623 - auc_1: 0.9998 - f1_score_1: 0.9802 - precision_2: 0.9955 - recall_2: 0.9892 - auc_2: 0.9999 - f1_score_2: 0.9923 - precision_3: 0.9868 - recall_3: 0.9632 - auc_3: 0.9968 - f1_score_3: 0.9748 - precision_4: 1.0000 - recall_4: 0.9722 - auc_4: 0.9998 - f1_score_4: 0.9858 - precision_5: 1.0000 - recall_5: 0.9572 - auc_5: 0.9991 - f1_score_5: 0.9780 - avg_f1_score: 0.9761 - avg_precision: 0.9924 - avg_recall: 0.9606 - avg_auc: 0.9985 - val_loss: 1.0680 - val_precision_0: 0.2000 - val_recall_0: 0.0541 - val_auc_0: 0.5311 - val_f1_score_0: 0.0851 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4866 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5349 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3611 - val_recall_3: 0.2281 - val_auc_3: 0.5563 - val_f1_score_3: 0.2796 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4966 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4727 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0608 - val_avg_precision: 0.0935 - val_avg_recall: 0.0470 - val_avg_auc: 0.5130
# Epoch 15/50
# 36/36 [==============================] - 15s 428ms/step - loss: 0.0263 - precision_0: 0.9615 - recall_0: 0.9673 - auc_0: 0.9992 - f1_score_0: 0.9643 - precision_1: 0.9442 - recall_1: 0.9588 - auc_1: 0.9993 - f1_score_1: 0.9509 - precision_2: 0.9502 - recall_2: 0.8887 - auc_2: 0.9713 - f1_score_2: 0.9179 - precision_3: 0.9937 - recall_3: 0.9749 - auc_3: 0.9971 - f1_score_3: 0.9842 - precision_4: 0.9840 - recall_4: 0.9493 - auc_4: 0.9958 - f1_score_4: 0.9661 - precision_5: 0.9785 - recall_5: 0.9262 - auc_5: 0.9960 - f1_score_5: 0.9511 - avg_f1_score: 0.9557 - avg_precision: 0.9687 - avg_recall: 0.9442 - avg_auc: 0.9931 - val_loss: 1.0282 - val_precision_0: 0.2500 - val_recall_0: 0.0541 - val_auc_0: 0.4924 - val_f1_score_0: 0.0889 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5107 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5545 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3000 - val_recall_3: 0.2105 - val_auc_3: 0.5640 - val_f1_score_3: 0.2474 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4651 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4476 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0561 - val_avg_precision: 0.0917 - val_avg_recall: 0.0441 - val_avg_auc: 0.5057
# Epoch 16/50
# 36/36 [==============================] - 17s 436ms/step - loss: 0.0230 - precision_0: 0.9837 - recall_0: 0.9679 - auc_0: 0.9999 - f1_score_0: 0.9748 - precision_1: 0.9953 - recall_1: 0.9946 - auc_1: 0.9996 - f1_score_1: 0.9950 - precision_2: 0.9622 - recall_2: 0.9746 - auc_2: 0.9967 - f1_score_2: 0.9683 - precision_3: 0.9991 - recall_3: 0.9948 - auc_3: 0.9998 - f1_score_3: 0.9969 - precision_4: 0.9718 - recall_4: 0.9488 - auc_4: 0.9988 - f1_score_4: 0.9599 - precision_5: 1.0000 - recall_5: 0.9290 - auc_5: 0.9958 - f1_score_5: 0.9629 - avg_f1_score: 0.9763 - avg_precision: 0.9854 - avg_recall: 0.9683 - avg_auc: 0.9984 - val_loss: 1.0246 - val_precision_0: 0.2500 - val_recall_0: 0.0541 - val_auc_0: 0.5005 - val_f1_score_0: 0.0889 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4882 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5365 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3226 - val_recall_3: 0.1754 - val_auc_3: 0.5475 - val_f1_score_3: 0.2273 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4551 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4387 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0527 - val_avg_precision: 0.0954 - val_avg_recall: 0.0382 - val_avg_auc: 0.4944
# Epoch 17/50
# 36/36 [==============================] - 17s 488ms/step - loss: 0.0207 - precision_0: 0.9658 - recall_0: 0.9708 - auc_0: 0.9995 - f1_score_0: 0.9682 - precision_1: 0.9775 - recall_1: 0.9696 - auc_1: 0.9988 - f1_score_1: 0.9734 - precision_2: 0.9862 - recall_2: 0.9723 - auc_2: 0.9998 - f1_score_2: 0.9791 - precision_3: 0.9976 - recall_3: 0.9855 - auc_3: 0.9978 - f1_score_3: 0.9915 - precision_4: 0.9451 - recall_4: 0.9906 - auc_4: 0.9989 - f1_score_4: 0.9670 - precision_5: 0.9874 - recall_5: 0.9664 - auc_5: 0.9997 - f1_score_5: 0.9767 - avg_f1_score: 0.9760 - avg_precision: 0.9766 - avg_recall: 0.9759 - avg_auc: 0.9991 - val_loss: 1.0202 - val_precision_0: 0.0000e+00 - val_recall_0: 0.0000e+00 - val_auc_0: 0.4869 - val_f1_score_0: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4507 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5490 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2791 - val_recall_3: 0.2105 - val_auc_3: 0.5497 - val_f1_score_3: 0.2400 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4690 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4376 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0400 - val_avg_precision: 0.0465 - val_avg_recall: 0.0351 - val_avg_auc: 0.4905
# Epoch 18/50
# 36/36 [==============================] - 15s 420ms/step - loss: 0.0225 - precision_0: 0.9973 - recall_0: 0.9364 - auc_0: 0.9979 - f1_score_0: 0.9658 - precision_1: 0.9862 - recall_1: 0.9964 - auc_1: 0.9999 - f1_score_1: 0.9912 - precision_2: 0.9789 - recall_2: 0.9208 - auc_2: 0.9997 - f1_score_2: 0.9488 - precision_3: 0.9534 - recall_3: 0.9781 - auc_3: 0.9990 - f1_score_3: 0.9652 - precision_4: 0.9873 - recall_4: 0.9280 - auc_4: 0.9909 - f1_score_4: 0.9566 - precision_5: 0.9825 - recall_5: 0.9974 - auc_5: 1.0000 - f1_score_5: 0.9899 - avg_f1_score: 0.9696 - avg_precision: 0.9809 - avg_recall: 0.9595 - avg_auc: 0.9979 - val_loss: 1.1446 - val_precision_0: 0.0000e+00 - val_recall_0: 0.0000e+00 - val_auc_0: 0.4971 - val_f1_score_0: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4618 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5471 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3333 - val_recall_3: 0.1228 - val_auc_3: 0.5662 - val_f1_score_3: 0.1795 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4934 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4327 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0299 - val_avg_precision: 0.0556 - val_avg_recall: 0.0205 - val_avg_auc: 0.4997
# Epoch 19/50
# 36/36 [==============================] - 19s 490ms/step - loss: 0.0191 - precision_0: 0.9973 - recall_0: 0.9707 - auc_0: 0.9999 - f1_score_0: 0.9838 - precision_1: 1.0000 - recall_1: 0.9665 - auc_1: 0.9997 - f1_score_1: 0.9828 - precision_2: 0.9861 - recall_2: 0.9904 - auc_2: 0.9999 - f1_score_2: 0.9883 - precision_3: 0.9758 - recall_3: 0.9870 - auc_3: 0.9995 - f1_score_3: 0.9813 - precision_4: 0.9507 - recall_4: 0.9834 - auc_4: 0.9969 - f1_score_4: 0.9666 - precision_5: 0.9687 - recall_5: 0.9315 - auc_5: 0.9723 - f1_score_5: 0.9496 - avg_f1_score: 0.9754 - avg_precision: 0.9798 - avg_recall: 0.9716 - avg_auc: 0.9947 - val_loss: 1.0855 - val_precision_0: 0.0000e+00 - val_recall_0: 0.0000e+00 - val_auc_0: 0.4793 - val_f1_score_0: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4548 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.3333 - val_recall_2: 0.0500 - val_auc_2: 0.5244 - val_f1_score_2: 0.0870 - val_precision_3: 0.2609 - val_recall_3: 0.1053 - val_auc_3: 0.5581 - val_f1_score_3: 0.1500 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4729 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4733 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0395 - val_avg_precision: 0.0990 - val_avg_recall: 0.0259 - val_avg_auc: 0.4938
# Epoch 20/50
# 36/36 [==============================] - 16s 435ms/step - loss: 0.0188 - precision_0: 0.9927 - recall_0: 0.9372 - auc_0: 0.9916 - f1_score_0: 0.9639 - precision_1: 0.9790 - recall_1: 0.9862 - auc_1: 0.9992 - f1_score_1: 0.9825 - precision_2: 0.9984 - recall_2: 0.9731 - auc_2: 0.9934 - f1_score_2: 0.9855 - precision_3: 0.9805 - recall_3: 0.9565 - auc_3: 0.9993 - f1_score_3: 0.9683 - precision_4: 0.9673 - recall_4: 0.9572 - auc_4: 0.9996 - f1_score_4: 0.9617 - precision_5: 0.9536 - recall_5: 0.9612 - auc_5: 0.9998 - f1_score_5: 0.9570 - avg_f1_score: 0.9698 - avg_precision: 0.9786 - avg_recall: 0.9619 - avg_auc: 0.9972 - val_loss: 1.1174 - val_precision_0: 0.2222 - val_recall_0: 0.0541 - val_auc_0: 0.5087 - val_f1_score_0: 0.0870 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4322 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.5000 - val_recall_2: 0.0500 - val_auc_2: 0.5597 - val_f1_score_2: 0.0909 - val_precision_3: 0.2821 - val_recall_3: 0.1930 - val_auc_3: 0.5512 - val_f1_score_3: 0.2292 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4748 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4451 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0678 - val_avg_precision: 0.1674 - val_avg_recall: 0.0495 - val_avg_auc: 0.4953
# Epoch 21/50
# 36/36 [==============================] - 17s 431ms/step - loss: 0.0171 - precision_0: 0.9929 - recall_0: 0.9619 - auc_0: 0.9998 - f1_score_0: 0.9771 - precision_1: 0.9638 - recall_1: 0.9523 - auc_1: 0.9918 - f1_score_1: 0.9579 - precision_2: 0.9896 - recall_2: 0.9584 - auc_2: 0.9991 - f1_score_2: 0.9735 - precision_3: 0.9851 - recall_3: 0.9870 - auc_3: 0.9996 - f1_score_3: 0.9860 - precision_4: 0.9906 - recall_4: 0.9716 - auc_4: 0.9992 - f1_score_4: 0.9809 - precision_5: 0.9681 - recall_5: 0.8735 - auc_5: 0.9998 - f1_score_5: 0.9147 - avg_f1_score: 0.9650 - avg_precision: 0.9817 - avg_recall: 0.9508 - avg_auc: 0.9982 - val_loss: 1.1534 - val_precision_0: 0.1667 - val_recall_0: 0.0270 - val_auc_0: 0.4902 - val_f1_score_0: 0.0465 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4699 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5289 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3684 - val_recall_3: 0.2456 - val_auc_3: 0.5553 - val_f1_score_3: 0.2947 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4911 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4490 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0569 - val_avg_precision: 0.0892 - val_avg_recall: 0.0454 - val_avg_auc: 0.4974
# Epoch 22/50
# 36/36 [==============================] - 15s 418ms/step - loss: 0.0144 - precision_0: 0.9996 - recall_0: 0.9456 - auc_0: 0.9995 - f1_score_0: 0.9716 - precision_1: 1.0000 - recall_1: 0.9955 - auc_1: 1.0000 - f1_score_1: 0.9978 - precision_2: 0.9839 - recall_2: 0.9910 - auc_2: 1.0000 - f1_score_2: 0.9874 - precision_3: 0.9977 - recall_3: 0.9894 - auc_3: 0.9996 - f1_score_3: 0.9935 - precision_4: 0.9529 - recall_4: 0.9744 - auc_4: 0.9983 - f1_score_4: 0.9634 - precision_5: 1.0000 - recall_5: 0.9816 - auc_5: 0.9999 - f1_score_5: 0.9907 - avg_f1_score: 0.9840 - avg_precision: 0.9890 - avg_recall: 0.9796 - avg_auc: 0.9995 - val_loss: 1.1758 - val_precision_0: 0.2000 - val_recall_0: 0.0541 - val_auc_0: 0.5267 - val_f1_score_0: 0.0851 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5052 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5552 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2973 - val_recall_3: 0.1930 - val_auc_3: 0.5550 - val_f1_score_3: 0.2340 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.5062 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4911 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0532 - val_avg_precision: 0.0829 - val_avg_recall: 0.0412 - val_avg_auc: 0.5232
# Epoch 23/50
# 36/36 [==============================] - 17s 428ms/step - loss: 0.0136 - precision_0: 0.9930 - recall_0: 0.9966 - auc_0: 0.9999 - f1_score_0: 0.9948 - precision_1: 0.9394 - recall_1: 0.9555 - auc_1: 0.9726 - f1_score_1: 0.9469 - precision_2: 0.9923 - recall_2: 0.9987 - auc_2: 1.0000 - f1_score_2: 0.9955 - precision_3: 0.9745 - recall_3: 0.9815 - auc_3: 0.9979 - f1_score_3: 0.9779 - precision_4: 0.9967 - recall_4: 0.9417 - auc_4: 0.9998 - f1_score_4: 0.9683 - precision_5: 0.9961 - recall_5: 0.9910 - auc_5: 1.0000 - f1_score_5: 0.9935 - avg_f1_score: 0.9795 - avg_precision: 0.9820 - avg_recall: 0.9775 - avg_auc: 0.9950 - val_loss: 1.3590 - val_precision_0: 0.0000e+00 - val_recall_0: 0.0000e+00 - val_auc_0: 0.5341 - val_f1_score_0: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4989 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5534 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2812 - val_recall_3: 0.1579 - val_auc_3: 0.5490 - val_f1_score_3: 0.2022 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.5302 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4588 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0337 - val_avg_precision: 0.0469 - val_avg_recall: 0.0263 - val_avg_auc: 0.5208
# Epoch 24/50
# 36/36 [==============================] - 17s 483ms/step - loss: 0.0148 - precision_0: 0.9869 - recall_0: 0.9853 - auc_0: 0.9997 - f1_score_0: 0.9860 - precision_1: 0.9682 - recall_1: 0.9731 - auc_1: 0.9996 - f1_score_1: 0.9704 - precision_2: 0.9790 - recall_2: 0.9800 - auc_2: 0.9996 - f1_score_2: 0.9794 - precision_3: 0.9942 - recall_3: 0.9854 - auc_3: 0.9997 - f1_score_3: 0.9897 - precision_4: 0.9750 - recall_4: 0.9851 - auc_4: 0.9998 - f1_score_4: 0.9800 - precision_5: 0.9386 - recall_5: 0.9570 - auc_5: 0.9979 - f1_score_5: 0.9468 - avg_f1_score: 0.9754 - avg_precision: 0.9736 - avg_recall: 0.9776 - avg_auc: 0.9994 - val_loss: 1.2521 - val_precision_0: 0.1429 - val_recall_0: 0.0270 - val_auc_0: 0.5447 - val_f1_score_0: 0.0455 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4929 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5199 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3182 - val_recall_3: 0.1228 - val_auc_3: 0.5258 - val_f1_score_3: 0.1772 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.5086 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4327 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0371 - val_avg_precision: 0.0768 - val_avg_recall: 0.0250 - val_avg_auc: 0.5041
# Epoch 25/50
# 36/36 [==============================] - 16s 438ms/step - loss: 0.0121 - precision_0: 1.0000 - recall_0: 0.9852 - auc_0: 0.9999 - f1_score_0: 0.9925 - precision_1: 0.9965 - recall_1: 0.9828 - auc_1: 1.0000 - f1_score_1: 0.9896 - precision_2: 1.0000 - recall_2: 0.9984 - auc_2: 0.9992 - f1_score_2: 0.9992 - precision_3: 0.9826 - recall_3: 0.9959 - auc_3: 0.9998 - f1_score_3: 0.9891 - precision_4: 0.9995 - recall_4: 0.9690 - auc_4: 0.9920 - f1_score_4: 0.9839 - precision_5: 1.0000 - recall_5: 0.9949 - auc_5: 1.0000 - f1_score_5: 0.9974 - avg_f1_score: 0.9920 - avg_precision: 0.9964 - avg_recall: 0.9877 - avg_auc: 0.9985 - val_loss: 1.2559 - val_precision_0: 0.1818 - val_recall_0: 0.0541 - val_auc_0: 0.4927 - val_f1_score_0: 0.0833 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4625 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5269 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2917 - val_recall_3: 0.1228 - val_auc_3: 0.5260 - val_f1_score_3: 0.1728 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4776 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4628 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0427 - val_avg_precision: 0.0789 - val_avg_recall: 0.0295 - val_avg_auc: 0.4914
# Epoch 26/50
# 36/36 [==============================] - 17s 417ms/step - loss: 0.0182 - precision_0: 0.9559 - recall_0: 0.9780 - auc_0: 0.9993 - f1_score_0: 0.9665 - precision_1: 0.9701 - recall_1: 0.9852 - auc_1: 0.9993 - f1_score_1: 0.9774 - precision_2: 0.9805 - recall_2: 0.9617 - auc_2: 0.9990 - f1_score_2: 0.9708 - precision_3: 0.9940 - recall_3: 0.9846 - auc_3: 0.9996 - f1_score_3: 0.9893 - precision_4: 0.9932 - recall_4: 0.9773 - auc_4: 0.9999 - f1_score_4: 0.9851 - precision_5: 0.9981 - recall_5: 0.9917 - auc_5: 1.0000 - f1_score_5: 0.9949 - avg_f1_score: 0.9807 - avg_precision: 0.9820 - avg_recall: 0.9797 - avg_auc: 0.9995 - val_loss: 1.1949 - val_precision_0: 0.2222 - val_recall_0: 0.0541 - val_auc_0: 0.5009 - val_f1_score_0: 0.0870 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4730 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5293 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2963 - val_recall_3: 0.1404 - val_auc_3: 0.5409 - val_f1_score_3: 0.1905 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.5128 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4705 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0462 - val_avg_precision: 0.0864 - val_avg_recall: 0.0324 - val_avg_auc: 0.5046
# Epoch 27/50
# 36/36 [==============================] - 15s 416ms/step - loss: 0.0142 - precision_0: 0.9829 - recall_0: 0.9796 - auc_0: 0.9998 - f1_score_0: 0.9811 - precision_1: 0.9684 - recall_1: 0.9772 - auc_1: 0.9988 - f1_score_1: 0.9727 - precision_2: 0.9847 - recall_2: 0.9902 - auc_2: 0.9999 - f1_score_2: 0.9874 - precision_3: 0.9976 - recall_3: 0.9858 - auc_3: 0.9999 - f1_score_3: 0.9916 - precision_4: 0.9933 - recall_4: 0.9574 - auc_4: 0.9994 - f1_score_4: 0.9749 - precision_5: 1.0000 - recall_5: 0.9933 - auc_5: 1.0000 - f1_score_5: 0.9966 - avg_f1_score: 0.9840 - avg_precision: 0.9878 - avg_recall: 0.9806 - avg_auc: 0.9996 - val_loss: 1.1925 - val_precision_0: 0.3333 - val_recall_0: 0.0541 - val_auc_0: 0.4982 - val_f1_score_0: 0.0930 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4564 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5457 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2000 - val_recall_3: 0.0877 - val_auc_3: 0.5530 - val_f1_score_3: 0.1220 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4883 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4603 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0358 - val_avg_precision: 0.0889 - val_avg_recall: 0.0236 - val_avg_auc: 0.5003
# Epoch 28/50
# 36/36 [==============================] - 17s 474ms/step - loss: 0.0115 - precision_0: 1.0000 - recall_0: 0.9903 - auc_0: 0.9999 - f1_score_0: 0.9951 - precision_1: 1.0000 - recall_1: 0.9621 - auc_1: 0.9999 - f1_score_1: 0.9806 - precision_2: 0.9914 - recall_2: 0.9869 - auc_2: 0.9932 - f1_score_2: 0.9891 - precision_3: 1.0000 - recall_3: 0.9760 - auc_3: 0.9958 - f1_score_3: 0.9878 - precision_4: 0.9937 - recall_4: 0.9791 - auc_4: 0.9999 - f1_score_4: 0.9863 - precision_5: 0.9883 - recall_5: 0.9087 - auc_5: 0.9997 - f1_score_5: 0.9465 - avg_f1_score: 0.9809 - avg_precision: 0.9956 - avg_recall: 0.9672 - avg_auc: 0.9981 - val_loss: 1.2696 - val_precision_0: 0.1667 - val_recall_0: 0.0270 - val_auc_0: 0.5391 - val_f1_score_0: 0.0465 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4791 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5341 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2667 - val_recall_3: 0.1404 - val_auc_3: 0.5429 - val_f1_score_3: 0.1839 - val_precision_4: 0.1429 - val_recall_4: 0.0286 - val_auc_4: 0.4765 - val_f1_score_4: 0.0476 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4308 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0463 - val_avg_precision: 0.0960 - val_avg_recall: 0.0327 - val_avg_auc: 0.5004
# Epoch 29/50
# 36/36 [==============================] - 15s 430ms/step - loss: 0.0152 - precision_0: 0.9775 - recall_0: 0.9561 - auc_0: 0.9851 - f1_score_0: 0.9665 - precision_1: 0.9647 - recall_1: 1.0000 - auc_1: 0.9999 - f1_score_1: 0.9820 - precision_2: 1.0000 - recall_2: 0.9761 - auc_2: 0.9972 - f1_score_2: 0.9878 - precision_3: 0.9778 - recall_3: 0.9801 - auc_3: 0.9998 - f1_score_3: 0.9789 - precision_4: 0.9927 - recall_4: 0.9920 - auc_4: 1.0000 - f1_score_4: 0.9923 - precision_5: 0.9814 - recall_5: 0.9618 - auc_5: 0.9996 - f1_score_5: 0.9714 - avg_f1_score: 0.9798 - avg_precision: 0.9823 - avg_recall: 0.9777 - avg_auc: 0.9969 - val_loss: 1.1500 - val_precision_0: 0.1538 - val_recall_0: 0.0541 - val_auc_0: 0.5368 - val_f1_score_0: 0.0800 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5049 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5302 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3125 - val_recall_3: 0.1754 - val_auc_3: 0.5312 - val_f1_score_3: 0.2247 - val_precision_4: 0.1667 - val_recall_4: 0.0286 - val_auc_4: 0.4851 - val_f1_score_4: 0.0488 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4487 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0589 - val_avg_precision: 0.1055 - val_avg_recall: 0.0430 - val_avg_auc: 0.5061
# Epoch 30/50
# 36/36 [==============================] - 17s 490ms/step - loss: 0.0195 - precision_0: 0.9958 - recall_0: 0.9661 - auc_0: 0.9999 - f1_score_0: 0.9807 - precision_1: 0.9735 - recall_1: 0.9920 - auc_1: 0.9977 - f1_score_1: 0.9825 - precision_2: 0.9615 - recall_2: 0.9815 - auc_2: 0.9995 - f1_score_2: 0.9713 - precision_3: 0.9954 - recall_3: 0.9802 - auc_3: 0.9964 - f1_score_3: 0.9877 - precision_4: 0.9686 - recall_4: 0.9634 - auc_4: 0.9954 - f1_score_4: 0.9655 - precision_5: 1.0000 - recall_5: 0.9459 - auc_5: 0.9981 - f1_score_5: 0.9721 - avg_f1_score: 0.9766 - avg_precision: 0.9825 - avg_recall: 0.9715 - avg_auc: 0.9978 - val_loss: 1.0795 - val_precision_0: 0.2143 - val_recall_0: 0.0811 - val_auc_0: 0.5214 - val_f1_score_0: 0.1176 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4585 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5252 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2647 - val_recall_3: 0.1579 - val_auc_3: 0.5348 - val_f1_score_3: 0.1978 - val_precision_4: 0.1429 - val_recall_4: 0.0286 - val_auc_4: 0.4803 - val_f1_score_4: 0.0476 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4552 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0605 - val_avg_precision: 0.1036 - val_avg_recall: 0.0446 - val_avg_auc: 0.4959
# Epoch 31/50
# 36/36 [==============================] - 15s 423ms/step - loss: 0.0151 - precision_0: 0.9388 - recall_0: 0.9634 - auc_0: 0.9726 - f1_score_0: 0.9504 - precision_1: 0.9781 - recall_1: 0.9860 - auc_1: 0.9998 - f1_score_1: 0.9820 - precision_2: 0.9841 - recall_2: 0.9863 - auc_2: 0.9998 - f1_score_2: 0.9852 - precision_3: 0.9939 - recall_3: 0.9981 - auc_3: 1.0000 - f1_score_3: 0.9960 - precision_4: 0.9718 - recall_4: 0.9812 - auc_4: 0.9997 - f1_score_4: 0.9764 - precision_5: 0.9114 - recall_5: 0.9730 - auc_5: 0.9729 - f1_score_5: 0.9406 - avg_f1_score: 0.9718 - avg_precision: 0.9630 - avg_recall: 0.9813 - avg_auc: 0.9908 - val_loss: 1.2128 - val_precision_0: 0.3333 - val_recall_0: 0.0541 - val_auc_0: 0.5277 - val_f1_score_0: 0.0930 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4845 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5095 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3182 - val_recall_3: 0.1228 - val_auc_3: 0.5322 - val_f1_score_3: 0.1772 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4837 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4733 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0450 - val_avg_precision: 0.1086 - val_avg_recall: 0.0295 - val_avg_auc: 0.5018
# Epoch 32/50
# 36/36 [==============================] - 17s 417ms/step - loss: 0.0114 - precision_0: 0.9960 - recall_0: 0.9733 - auc_0: 0.9999 - f1_score_0: 0.9844 - precision_1: 0.9914 - recall_1: 1.0000 - auc_1: 1.0000 - f1_score_1: 0.9957 - precision_2: 0.9881 - recall_2: 0.9941 - auc_2: 0.9999 - f1_score_2: 0.9911 - precision_3: 0.9955 - recall_3: 0.9806 - auc_3: 0.9999 - f1_score_3: 0.9880 - precision_4: 0.9832 - recall_4: 0.9807 - auc_4: 0.9965 - f1_score_4: 0.9819 - precision_5: 1.0000 - recall_5: 0.9989 - auc_5: 1.0000 - f1_score_5: 0.9994 - avg_f1_score: 0.9901 - avg_precision: 0.9924 - avg_recall: 0.9879 - avg_auc: 0.9994 - val_loss: 1.1733 - val_precision_0: 0.2000 - val_recall_0: 0.0541 - val_auc_0: 0.4938 - val_f1_score_0: 0.0851 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5020 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5092 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3333 - val_recall_3: 0.1404 - val_auc_3: 0.5357 - val_f1_score_3: 0.1975 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4779 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4626 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0471 - val_avg_precision: 0.0889 - val_avg_recall: 0.0324 - val_avg_auc: 0.4968
# Epoch 33/50
# 36/36 [==============================] - 17s 478ms/step - loss: 0.0101 - precision_0: 1.0000 - recall_0: 0.9510 - auc_0: 0.9933 - f1_score_0: 0.9746 - precision_1: 0.9858 - recall_1: 0.9849 - auc_1: 0.9999 - f1_score_1: 0.9853 - precision_2: 0.9683 - recall_2: 0.9691 - auc_2: 0.9729 - f1_score_2: 0.9687 - precision_3: 0.9936 - recall_3: 0.9961 - auc_3: 1.0000 - f1_score_3: 0.9948 - precision_4: 1.0000 - recall_4: 0.9856 - auc_4: 0.9926 - f1_score_4: 0.9927 - precision_5: 0.9668 - recall_5: 0.9198 - auc_5: 0.9996 - f1_score_5: 0.9426 - avg_f1_score: 0.9765 - avg_precision: 0.9857 - avg_recall: 0.9678 - avg_auc: 0.9931 - val_loss: 1.4866 - val_precision_0: 0.1667 - val_recall_0: 0.0270 - val_auc_0: 0.5167 - val_f1_score_0: 0.0465 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4899 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5021 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3750 - val_recall_3: 0.1053 - val_auc_3: 0.5411 - val_f1_score_3: 0.1644 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4991 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4462 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0351 - val_avg_precision: 0.0903 - val_avg_recall: 0.0220 - val_avg_auc: 0.4992
# Epoch 34/50
# 36/36 [==============================] - 15s 432ms/step - loss: 0.0097 - precision_0: 1.0000 - recall_0: 0.9554 - auc_0: 1.0000 - f1_score_0: 0.9770 - precision_1: 0.9302 - recall_1: 0.9714 - auc_1: 0.9727 - f1_score_1: 0.9492 - precision_2: 0.9724 - recall_2: 0.9668 - auc_2: 0.9730 - f1_score_2: 0.9695 - precision_3: 0.9952 - recall_3: 0.9874 - auc_3: 0.9991 - f1_score_3: 0.9913 - precision_4: 0.9906 - recall_4: 0.9988 - auc_4: 1.0000 - f1_score_4: 0.9947 - precision_5: 0.9961 - recall_5: 0.9961 - auc_5: 1.0000 - f1_score_5: 0.9961 - avg_f1_score: 0.9796 - avg_precision: 0.9807 - avg_recall: 0.9793 - avg_auc: 0.9908 - val_loss: 1.2866 - val_precision_0: 0.1667 - val_recall_0: 0.0541 - val_auc_0: 0.5057 - val_f1_score_0: 0.0816 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4812 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5127 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2500 - val_recall_3: 0.1228 - val_auc_3: 0.5359 - val_f1_score_3: 0.1647 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4833 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4308 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0411 - val_avg_precision: 0.0694 - val_avg_recall: 0.0295 - val_avg_auc: 0.4916
# Epoch 35/50
# ...
# Epoch 40/50
# 36/36 [==============================] - 15s 416ms/step - loss: 0.0151 - precision_0: 0.9706 - recall_0: 0.9826 - auc_0: 0.9999 - f1_score_0: 0.9765 - precision_1: 0.9993 - recall_1: 0.9916 - auc_1: 0.9999 - f1_score_1: 0.9954 - precision_2: 0.9959 - recall_2: 0.9477 - auc_2: 0.9999 - f1_score_2: 0.9710 - precision_3: 0.9933 - recall_3: 0.9761 - auc_3: 0.9998 - f1_score_3: 0.9843 - precision_4: 0.9846 - recall_4: 0.9627 - auc_4: 0.9957 - f1_score_4: 0.9735 - precision_5: 0.9662 - recall_5: 0.9819 - auc_5: 0.9997 - f1_score_5: 0.9739 - avg_f1_score: 0.9791 - avg_precision: 0.9850 - avg_recall: 0.9738 - avg_auc: 0.9991 - val_loss: 1.1118 - val_precision_0: 0.2500 - val_recall_0: 0.0270 - val_auc_0: 0.4958 - val_f1_score_0: 0.0488 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4899 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5585 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3200 - val_recall_3: 0.1404 - val_auc_3: 0.5356 - val_f1_score_3: 0.1951 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4600 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4329 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0407 - val_avg_precision: 0.0950 - val_avg_recall: 0.0279 - val_avg_auc: 0.4954
# Epoch 41/50
# 36/36 [==============================] - 17s 421ms/step - loss: 0.0138 - precision_0: 1.0000 - recall_0: 0.9990 - auc_0: 1.0000 - f1_score_0: 0.9995 - precision_1: 0.9963 - recall_1: 0.9917 - auc_1: 0.9999 - f1_score_1: 0.9940 - precision_2: 0.8887 - recall_2: 0.9217 - auc_2: 0.9420 - f1_score_2: 0.9040 - precision_3: 0.9869 - recall_3: 0.9902 - auc_3: 0.9998 - f1_score_3: 0.9885 - precision_4: 0.9778 - recall_4: 0.9879 - auc_4: 0.9976 - f1_score_4: 0.9828 - precision_5: 0.9907 - recall_5: 0.9726 - auc_5: 0.9999 - f1_score_5: 0.9815 - avg_f1_score: 0.9750 - avg_precision: 0.9734 - avg_recall: 0.9772 - avg_auc: 0.9899 - val_loss: 1.2436 - val_precision_0: 0.2500 - val_recall_0: 0.0270 - val_auc_0: 0.4905 - val_f1_score_0: 0.0488 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4886 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5382 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3214 - val_recall_3: 0.1579 - val_auc_3: 0.5354 - val_f1_score_3: 0.2118 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4993 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4308 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0434 - val_avg_precision: 0.0952 - val_avg_recall: 0.0308 - val_avg_auc: 0.4971
# Epoch 42/50
# 36/36 [==============================] - 15s 416ms/step - loss: 0.0091 - precision_0: 0.9934 - recall_0: 0.9850 - auc_0: 0.9999 - f1_score_0: 0.9892 - precision_1: 1.0000 - recall_1: 0.9845 - auc_1: 1.0000 - f1_score_1: 0.9922 - precision_2: 1.0000 - recall_2: 0.9981 - auc_2: 1.0000 - f1_score_2: 0.9990 - precision_3: 1.0000 - recall_3: 0.9971 - auc_3: 1.0000 - f1_score_3: 0.9985 - precision_4: 0.9739 - recall_4: 0.9991 - auc_4: 0.9999 - f1_score_4: 0.9863 - precision_5: 1.0000 - recall_5: 0.9615 - auc_5: 0.9999 - f1_score_5: 0.9803 - avg_f1_score: 0.9909 - avg_precision: 0.9945 - avg_recall: 0.9876 - avg_auc: 0.9999 - val_loss: 1.3705 - val_precision_0: 0.1429 - val_recall_0: 0.0270 - val_auc_0: 0.5023 - val_f1_score_0: 0.0455 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5043 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5181 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2857 - val_recall_3: 0.1404 - val_auc_3: 0.5524 - val_f1_score_3: 0.1882 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4899 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4404 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0389 - val_avg_precision: 0.0714 - val_avg_recall: 0.0279 - val_avg_auc: 0.5012
# Epoch 43/50
# 36/36 [==============================] - 17s 429ms/step - loss: 0.0046 - precision_0: 1.0000 - recall_0: 0.9994 - auc_0: 1.0000 - f1_score_0: 0.9997 - precision_1: 1.0000 - recall_1: 1.0000 - auc_1: 1.0000 - f1_score_1: 1.0000 - precision_2: 0.9952 - recall_2: 0.9921 - auc_2: 1.0000 - f1_score_2: 0.9937 - precision_3: 0.9956 - recall_3: 1.0000 - auc_3: 1.0000 - f1_score_3: 0.9978 - precision_4: 1.0000 - recall_4: 0.9845 - auc_4: 0.9999 - f1_score_4: 0.9922 - precision_5: 0.9950 - recall_5: 0.9909 - auc_5: 1.0000 - f1_score_5: 0.9929 - avg_f1_score: 0.9960 - avg_precision: 0.9976 - avg_recall: 0.9945 - avg_auc: 1.0000 - val_loss: 1.4383 - val_precision_0: 0.1429 - val_recall_0: 0.0270 - val_auc_0: 0.5013 - val_f1_score_0: 0.0455 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4879 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5035 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3636 - val_recall_3: 0.1404 - val_auc_3: 0.5536 - val_f1_score_3: 0.2025 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.5102 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4365 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0413 - val_avg_precision: 0.0844 - val_avg_recall: 0.0279 - val_avg_auc: 0.4988
# Epoch 44/50
# 36/36 [==============================] - 17s 427ms/step - loss: 0.0080 - precision_0: 0.9820 - recall_0: 0.9829 - auc_0: 0.9998 - f1_score_0: 0.9824 - precision_1: 0.9871 - recall_1: 0.9971 - auc_1: 0.9994 - f1_score_1: 0.9921 - precision_2: 1.0000 - recall_2: 0.9934 - auc_2: 1.0000 - f1_score_2: 0.9967 - precision_3: 1.0000 - recall_3: 0.9847 - auc_3: 1.0000 - f1_score_3: 0.9923 - precision_4: 0.9996 - recall_4: 0.9915 - auc_4: 1.0000 - f1_score_4: 0.9955 - precision_5: 1.0000 - recall_5: 1.0000 - auc_5: 1.0000 - f1_score_5: 1.0000 - avg_f1_score: 0.9932 - avg_precision: 0.9948 - avg_recall: 0.9916 - avg_auc: 0.9998 - val_loss: 1.3366 - val_precision_0: 0.1667 - val_recall_0: 0.0270 - val_auc_0: 0.5055 - val_f1_score_0: 0.0465 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4788 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5123 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2727 - val_recall_3: 0.1579 - val_auc_3: 0.5510 - val_f1_score_3: 0.2000 - val_precision_4: 0.0909 - val_recall_4: 0.0286 - val_auc_4: 0.5147 - val_f1_score_4: 0.0435 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4510 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0483 - val_avg_precision: 0.0884 - val_avg_recall: 0.0356 - val_avg_auc: 0.5022
# Epoch 45/50
# 36/36 [==============================] - 17s 418ms/step - loss: 0.0111 - precision_0: 0.9979 - recall_0: 0.9413 - auc_0: 0.9997 - f1_score_0: 0.9666 - precision_1: 0.9921 - recall_1: 0.9682 - auc_1: 1.0000 - f1_score_1: 0.9790 - precision_2: 0.9938 - recall_2: 0.9817 - auc_2: 0.9998 - f1_score_2: 0.9877 - precision_3: 0.9994 - recall_3: 0.9892 - auc_3: 0.9978 - f1_score_3: 0.9942 - precision_4: 0.9737 - recall_4: 0.9811 - auc_4: 0.9999 - f1_score_4: 0.9771 - precision_5: 0.9937 - recall_5: 0.9968 - auc_5: 0.9997 - f1_score_5: 0.9952 - avg_f1_score: 0.9833 - avg_precision: 0.9918 - avg_recall: 0.9764 - avg_auc: 0.9995 - val_loss: 1.3863 - val_precision_0: 0.2000 - val_recall_0: 0.0270 - val_auc_0: 0.5010 - val_f1_score_0: 0.0476 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4815 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5107 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3103 - val_recall_3: 0.1579 - val_auc_3: 0.5518 - val_f1_score_3: 0.2093 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4750 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4442 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0428 - val_avg_precision: 0.0851 - val_avg_recall: 0.0308 - val_avg_auc: 0.4940
# Epoch 46/50
# 36/36 [==============================] - 17s 484ms/step - loss: 0.0103 - precision_0: 0.9764 - recall_0: 0.9867 - auc_0: 0.9976 - f1_score_0: 0.9815 - precision_1: 0.9867 - recall_1: 0.9271 - auc_1: 0.9996 - f1_score_1: 0.9547 - precision_2: 1.0000 - recall_2: 1.0000 - auc_2: 1.0000 - f1_score_2: 1.0000 - precision_3: 0.9823 - recall_3: 0.9944 - auc_3: 1.0000 - f1_score_3: 0.9882 - precision_4: 0.9762 - recall_4: 0.9808 - auc_4: 0.9998 - f1_score_4: 0.9785 - precision_5: 0.9736 - recall_5: 0.9889 - auc_5: 1.0000 - f1_score_5: 0.9810 - avg_f1_score: 0.9807 - avg_precision: 0.9825 - avg_recall: 0.9796 - avg_auc: 0.9995 - val_loss: 1.4297 - val_precision_0: 0.5000 - val_recall_0: 0.0270 - val_auc_0: 0.5186 - val_f1_score_0: 0.0513 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4606 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5047 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3043 - val_recall_3: 0.1228 - val_auc_3: 0.5373 - val_f1_score_3: 0.1750 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.4896 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4500 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0377 - val_avg_precision: 0.1341 - val_avg_recall: 0.0250 - val_avg_auc: 0.4935
# Epoch 47/50
# 36/36 [==============================] - 18s 493ms/step - loss: 0.0128 - precision_0: 0.9989 - recall_0: 0.9751 - auc_0: 0.9999 - f1_score_0: 0.9868 - precision_1: 0.9678 - recall_1: 0.9536 - auc_1: 0.9996 - f1_score_1: 0.9599 - precision_2: 0.9782 - recall_2: 1.0000 - auc_2: 0.9999 - f1_score_2: 0.9889 - precision_3: 1.0000 - recall_3: 0.9913 - auc_3: 1.0000 - f1_score_3: 0.9956 - precision_4: 0.9914 - recall_4: 0.9773 - auc_4: 0.9994 - f1_score_4: 0.9842 - precision_5: 0.9797 - recall_5: 0.9898 - auc_5: 0.9998 - f1_score_5: 0.9847 - avg_f1_score: 0.9834 - avg_precision: 0.9860 - avg_recall: 0.9812 - avg_auc: 0.9998 - val_loss: 1.3774 - val_precision_0: 0.2500 - val_recall_0: 0.0270 - val_auc_0: 0.5200 - val_f1_score_0: 0.0488 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4793 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5133 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.3500 - val_recall_3: 0.1228 - val_auc_3: 0.5493 - val_f1_score_3: 0.1818 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.5024 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4442 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0384 - val_avg_precision: 0.1000 - val_avg_recall: 0.0250 - val_avg_auc: 0.5014
# Epoch 48/50
# 36/36 [==============================] - 17s 488ms/step - loss: 0.0083 - precision_0: 0.9886 - recall_0: 1.0000 - auc_0: 1.0000 - f1_score_0: 0.9942 - precision_1: 0.9996 - recall_1: 1.0000 - auc_1: 1.0000 - f1_score_1: 0.9998 - precision_2: 1.0000 - recall_2: 1.0000 - auc_2: 1.0000 - f1_score_2: 1.0000 - precision_3: 0.9976 - recall_3: 0.9937 - auc_3: 0.9998 - f1_score_3: 0.9957 - precision_4: 0.9712 - recall_4: 0.9638 - auc_4: 0.9970 - f1_score_4: 0.9674 - precision_5: 0.9831 - recall_5: 0.9878 - auc_5: 1.0000 - f1_score_5: 0.9854 - avg_f1_score: 0.9904 - avg_precision: 0.9900 - avg_recall: 0.9909 - avg_auc: 0.9995 - val_loss: 1.3727 - val_precision_0: 0.1667 - val_recall_0: 0.0270 - val_auc_0: 0.5051 - val_f1_score_0: 0.0465 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4691 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5173 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2581 - val_recall_3: 0.1404 - val_auc_3: 0.5605 - val_f1_score_3: 0.1818 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.5012 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4346 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0381 - val_avg_precision: 0.0708 - val_avg_recall: 0.0279 - val_avg_auc: 0.4980
# Epoch 49/50
# 36/36 [==============================] - 15s 425ms/step - loss: 0.0098 - precision_0: 0.9731 - recall_0: 0.9773 - auc_0: 0.9945 - f1_score_0: 0.9751 - precision_1: 1.0000 - recall_1: 0.9906 - auc_1: 1.0000 - f1_score_1: 0.9952 - precision_2: 1.0000 - recall_2: 0.9435 - auc_2: 0.9997 - f1_score_2: 0.9686 - precision_3: 0.9923 - recall_3: 1.0000 - auc_3: 1.0000 - f1_score_3: 0.9961 - precision_4: 0.9921 - recall_4: 0.9838 - auc_4: 0.9997 - f1_score_4: 0.9878 - precision_5: 1.0000 - recall_5: 0.9758 - auc_5: 0.9999 - f1_score_5: 0.9876 - avg_f1_score: 0.9851 - avg_precision: 0.9929 - avg_recall: 0.9785 - avg_auc: 0.9990 - val_loss: 1.3591 - val_precision_0: 0.1111 - val_recall_0: 0.0270 - val_auc_0: 0.5192 - val_f1_score_0: 0.0435 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4660 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5178 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2800 - val_recall_3: 0.1228 - val_auc_3: 0.5585 - val_f1_score_3: 0.1707 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.5097 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4327 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0357 - val_avg_precision: 0.0652 - val_avg_recall: 0.0250 - val_avg_auc: 0.5007
# Epoch 50/50
# 36/36 [==============================] - 17s 421ms/step - loss: 0.0101 - precision_0: 0.9902 - recall_0: 0.9845 - auc_0: 0.9999 - f1_score_0: 0.9874 - precision_1: 0.9916 - recall_1: 0.9986 - auc_1: 0.9987 - f1_score_1: 0.9951 - precision_2: 0.9937 - recall_2: 1.0000 - auc_2: 1.0000 - f1_score_2: 0.9968 - precision_3: 0.9996 - recall_3: 0.9787 - auc_3: 0.9952 - f1_score_3: 0.9890 - precision_4: 0.9983 - recall_4: 0.9868 - auc_4: 1.0000 - f1_score_4: 0.9925 - precision_5: 0.9827 - recall_5: 0.9639 - auc_5: 1.0000 - f1_score_5: 0.9729 - avg_f1_score: 0.9890 - avg_precision: 0.9927 - avg_recall: 0.9854 - avg_auc: 0.9989 - val_loss: 1.2338 - val_precision_0: 0.2500 - val_recall_0: 0.0811 - val_auc_0: 0.4917 - val_f1_score_0: 0.1224 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.4719 - val_f1_score_1: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5139 - val_f1_score_2: 0.0000e+00 - val_precision_3: 0.2000 - val_recall_3: 0.1228 - val_auc_3: 0.5515 - val_f1_score_3: 0.1522 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_4: 0.5080 - val_f1_score_4: 0.0000e+00 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_5: 0.4250 - val_f1_score_5: 0.0000e+00 - val_avg_f1_score: 0.0458 - val_avg_precision: 0.0750 - val_avg_recall: 0.0340 - val_avg_auc: 0.4937

# %%
# Save the model for later use
model.save('my_model_samples.h5')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ---

# %% [markdown]
# Next let's plot loss and all evaluation metrics for training and validation sets

# %%
# Print all keys in the history object
print(history.history.keys())
# Out:
# dict_keys(['loss', 'precision_0', 'recall_0', 'auc_0', 'f1_score_0', 'precision_1', 'recall_1', 'auc_1', 'f1_score_1', 'precision_2', 'recall_2', 'auc_2', 'f1_score_2', 'precision_3', 'recall_3', 'auc_3', 'f1_score_3', 'precision_4', 'recall_4', 'auc_4', 'f1_score_4', 'precision_5', 'recall_5', 'auc_5', 'f1_score_5', 'avg_f1_score', 'avg_precision', 'avg_recall', 'avg_auc', 'val_loss', 'val_precision_0', 'val_recall_0', 'val_auc_0', 'val_f1_score_0', 'val_precision_1', 'val_recall_1', 'val_auc_1', 'val_f1_score_1', 'val_precision_2', 'val_recall_2', 'val_auc_2', 'val_f1_score_2', 'val_precision_3', 'val_recall_3', 'val_auc_3', 'val_f1_score_3', 'val_precision_4', 'val_recall_4', 'val_auc_4', 'val_f1_score_4', 'val_precision_5', 'val_recall_5', 'val_auc_5', 'val_f1_score_5', 'val_avg_f1_score', 'val_avg_precision', 'val_avg_recall', 'val_avg_auc'])

# %%
def plot_training_history(history):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))

    # Plot Loss
    axes[0, 0].plot(history.history['loss'], label='Train Loss')
    axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0, 0].set_title('Loss Over Epochs')
    axes[0, 0].set_xlabel('Epoch')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()

    # Plot Average F1 Score
    axes[0, 1].plot(history.history['avg_f1_score'], label='Train Avg F1 Score')
    axes[0, 1].plot(history.history['val_avg_f1_score'], label='Validation Avg F1 Score')
    axes[0, 1].set_title('Average F1 Score Over Epochs')
    axes[0, 1].set_xlabel('Epoch')
    axes[0, 1].set_ylabel('Average F1 Score')
    axes[0, 1].legend()

    # Plot Average Precision
    axes[1, 0].plot(history.history['avg_precision'], label='Train Avg Precision')
    axes[1, 0].plot(history.history['val_avg_precision'], label='Validation Avg Precision')
    axes[1, 0].set_title('Average Precision Over Epochs')
    axes[1, 0].set_xlabel('Epoch')
    axes[1, 0].set_ylabel('Average Precision')
    axes[1, 0].legend()

    # Plot Average Recall
    axes[1, 1].plot(history.history['avg_recall'], label='Train Avg Recall')
    axes[1, 1].plot(history.history['val_avg_recall'], label='Validation Avg Recall')
    axes[1, 1].set_title('Average Recall Over Epochs')
    axes[1, 1].set_xlabel('Epoch')
    axes[1, 1].set_ylabel('Average Recall')
    axes[1, 1].legend()

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# %% [markdown]
# Let's predict the test samples

# %%
predictions = model.predict(test_generator, steps=np.ceil(test_generator.samples / test_generator.batch_size))

# Binarize predictions with a threshold of 0.5
predictions_binarized = (predictions > 0.5).astype(int)

# Ensure 'true_labels' is properly defined; it should be an array of shape (num_samples, num_labels)
# If 'y_test' is a DataFrame, you can convert it to a NumPy array using 'y_test.values'
true_labels = y_test.values
# Out:
# 9/9 [==============================] - 4s 427ms/step

# %% [markdown]
# Let's plot CMs

# %%
# Initialize variables to accumulate scores
total_precision = 0
total_recall = 0
total_f1 = 0
total_auc = 0

# Plot confusion matrices for each label and calculate metrics
for i, label in enumerate(y_columns):
    plt.figure(figsize=(5, 4))
    cm = confusion_matrix(true_labels[:, i], predictions_binarized[:, i])
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'Confusion Matrix for {label}')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    
    # Calculate and print individual metrics
    precision = precision_score(true_labels[:, i], predictions_binarized[:, i], zero_division=0)
    recall = recall_score(true_labels[:, i], predictions_binarized[:, i], zero_division=0)
    f1 = f1_score(true_labels[:, i], predictions_binarized[:, i], zero_division=0)
    auc = roc_auc_score(true_labels[:, i], predictions[:, i])  # Use non-binarized predictions for AUC

    # Accumulate to compute average
    total_precision += precision
    total_recall += recall
    total_f1 += f1
    total_auc += auc

    plt.figtext(0.5, -0.1, f'Precision: {precision:.2f} | Recall: {recall:.2f} | F1 Score: {f1:.2f} | AUC: {auc:.2f}', ha='center', fontsize=12)
    plt.show()

# Calculate and print average metrics
avg_precision = total_precision / len(y_columns)
avg_recall = total_recall / len(y_columns)
avg_f1 = total_f1 / len(y_columns)
avg_auc = total_auc / len(y_columns)
print(f'Average Precision: {avg_precision:.2f}')
print(f'Average Recall: {avg_recall:.2f}')
print(f'Average F1 Score: {avg_f1:.2f}')
print(f'Average AUC: {avg_auc:.2f}')
# Out:
# Average Precision: 0.17
# Average Recall: 0.04
# Average F1 Score: 0.06
# Average AUC: 0.57

# %% [markdown]
# ---
